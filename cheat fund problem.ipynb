# %% [markdown]
# Problem Statement :
#
# A chit fund has 25 members. Each month they contribute Rs 2000 each. End of the month, the person who bids the lowest for the corpus, gets his bid. The group organizer gets paid a fixed commission of Rs 2500 each month (5% of 25*2000).It is deducted from the bid winner's corpus. The remaining amount is distributed among all the 25 customers equally.
#
#
# Task : • What is the Annualized Return of the person who bids in the last month ? • What is the Annualized Return of the person who bids in the first month ? • Write an R/Python script which calculates the annualized return of chit fund participant ?- Show the Return % for each month's bid winner.

# %%
#importing required libraries
import pandas as pd
import seaborn as sns

# %%
#importing data
data = pd.read_excel('Exercise Data.xlsx',header=0)

# %%
data.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400

# %%
data.describe()
# Out:
#            Month  Contribution  Amount won by the bidder  \
# count  25.000000          25.0                 25.000000
# mean   13.000000        2000.0              43800.000000
# std     7.359801           0.0               2857.738033
# min     1.000000        2000.0              40000.000000
# 25%     7.000000        2000.0              42000.000000
# 50%    13.000000        2000.0              43000.000000
# 75%    19.000000        2000.0              45000.000000
# max    25.000000        2000.0              50000.000000
#
#        Chit fund organizer commission  Net amount recd by Bid winner  \
# count                            25.0                      25.000000
# mean                           2500.0                   41300.000000
# std                               0.0                    2857.738033
# min                            2500.0                   37500.000000
# 25%                            2500.0                   39500.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Month                                     25 non-null     int64
#  1   Contribution                              25 non-null     int64
#  2   Amount won by the bidder                  25 non-null     int64
#  3   Chit fund organizer commission            25 non-null     int64
#  4   Net amount recd by Bid winner             25 non-null     int64
#  5   Amount returned to everyone in the group  25 non-null     int64
# dtypes: int64(6)
# memory usage: 1.3 KB

# %%
data.isnull().sum()
# Out:
# Month                                       0
# Contribution                                0
# Amount won by the bidder                    0
# Chit fund organizer commission              0
# Net amount recd by Bid winner               0
# Amount returned to everyone in the group    0
# dtype: int64

# %%
data['Amount returned to everyone in the group'].sum()
# Out:
# 6200

# %%
# creating new columns and summing it by each value.
list = []
new_col = data['Amount returned to everyone in the group']
sum = 0
list.append(0)
for num in new_col:
    sum += num
    list.append(sum)

# %%
list
# Out:
# [0,
#  400,
#  720,
#  920,
#  1000,
#  1400,
#  1720,
#  2000,
#  2240,
#  2640,
#  2960,
#  3160,
#  3240,
#  3640,
#  3960,
#  4240,
#  4520,
#  4880,
#  5200,
#  5400,
#  5600,
#  5840,
#  6000,
#  6120,
#  6200,
#  6200]

# %%
new_list = list[:25]

# %%
new_list
# Out:
# [0,
#  400,
#  720,
#  920,
#  1000,
#  1400,
#  1720,
#  2000,
#  2240,
#  2640,
#  2960,
#  3160,
#  3240,
#  3640,
#  3960,
#  4240,
#  4520,
#  4880,
#  5200,
#  5400,
#  5600,
#  5840,
#  6000,
#  6120,
#  6200]

# %%
data['Remaining amount returned to bid winner']=new_list

# %%
data.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
# ...

# %%
data['Total amount returned to winner'] = data['Net amount recd by Bid winner'] + data['Remaining amount returned to bid winner']

# %%
data.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
# ...

# %%
 data['Return percentage of each month bid winner'] = (data['Total amount returned to winner']/50000)*100

# %%
data
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
sns.distplot(data['Total amount returned to winner'], kde=False, bins=10, color='r')
# Out:
# C:\Users\DAYANAND SHAH\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total amount returned to winner'>

# %%
data[['Total amount returned to winner','Return percentage of each month bid winner']]
# Out:
#     Total amount returned to winner  \
# 0                             37500
# 1                             39900
# 2                             43220
# 3                             46420
# 4                             38500
# 5                             40900
# 6                             42220
# 7                             43500
# 8                             39740
# 9                             42140
# 10                            45460
# 11                            48660
# 12                            40740
# 13                            43140
# 14                            44460
# 15                            44740
# 16                            43020
# 17                            44380
# 18                            47700
# 19                            47900
# 20                            47100
# 21                            49340
# 22                            50500
# 23                            51620
# 24                            53700
#
# ...

# %% [markdown]
# Questions.

# %% [markdown]
# 1. What is the Annualized Return of the person who bids in the last month ?

# %%
data.tail()
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 20     21          2000                     44000
# 21     22          2000                     46000
# 22     23          2000                     47000
# 23     24          2000                     48000
# 24     25          2000                     50000
#
#     Chit fund organizer commission  Net amount recd by Bid winner  \
# 20                            2500                          41500
# 21                            2500                          43500
# 22                            2500                          44500
# 23                            2500                          45500
# 24                            2500                          47500
#
#     Amount returned to everyone in the group  \
# 20                                       240
# 21                                       160
# 22                                       120
# 23                                        80
# ...

# %% [markdown]
# 25 months invetsed 2000 per month = 50,000
#
# Returns= 53700rs - return percentage 107.40%

# %% [markdown]
# 2. What is the Annualized Return of the person who bids in the first month ?

# %%
data.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
# ...

# %% [markdown]
# 25 months- invetsed 2000 per month = 50,000
#
# Returns= 37500rs - return percentage 75.00%

# %% [markdown]
# 3.Write an R/Python script which calculates the annualized return of chit fund participant ?- Show the Return % for each month's bid winner.

# %%
data[['Month','Total amount returned to winner','Return percentage of each month bid winner']]
# Out:
#     Month  Total amount returned to winner  \
# 0       1                            37500
# 1       2                            39900
# 2       3                            43220
# 3       4                            46420
# 4       5                            38500
# 5       6                            40900
# 6       7                            42220
# 7       8                            43500
# 8       9                            39740
# 9      10                            42140
# 10     11                            45460
# 11     12                            48660
# 12     13                            40740
# 13     14                            43140
# 14     15                            44460
# 15     16                            44740
# 16     17                            43020
# 17     18                            44380
# 18     19                            47700
# 19     20                            47900
# 20     21                            47100
# ...

# %% [markdown]
# # Thats all for this task. Thank you!!!
